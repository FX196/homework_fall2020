# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yonzhang/opt/anaconda3/envs/cs285/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def get_section_results(file, keys=['Eval_AverageReturn']):
    eval_returns_dict = {}
    for k in keys:
        eval_returns_dict[k] = []
    for e in tf.train.summary_iterator(file):
        for v in e.summary.value:
            if v.tag in keys:
                eval_returns_dict[v.tag].append(v.simple_value)
    for k in keys:
        eval_returns_dict[k] = np.array(eval_returns_dict[k])
    return eval_returns_dict

# %%
q1_sb_files = {"small_scale_data/q1_sb_no_rtg_dsa_CartPole-v0_26-09-2020_18-36-19/events.out.tfevents.1601170579.heisenberg": "no_rtg_dsa", 
               "small_scale_data/q1_sb_rtg_dsa_CartPole-v0_26-09-2020_18-36-17/events.out.tfevents.1601170577.heisenberg": "rtg_dsa", 
               "small_scale_data/q1_sb_rtg_na_CartPole-v0_26-09-2020_18-36-13/events.out.tfevents.1601170573.heisenberg": "rtg_na"}

q1_lb_files = {"small_scale_data/q1_lb_no_rtg_dsa_5000_CartPole-v0_26-09-2020_18-36-15/events.out.tfevents.1601170575.heisenberg": "no_rtg_dsa", 
               "small_scale_data/q1_lb_rtg_dsa_5000_CartPole-v0_26-09-2020_18-36-09/events.out.tfevents.1601170569.heisenberg": "rtg_dsa",
               "small_scale_data/q1_lb_rtg_na_5000_CartPole-v0_26-09-2020_18-36-08/events.out.tfevents.1601170568.heisenberg": "rtg_na"}

# %%
def plot_q5(files_label_dict, title):
    for f in files_label_dict.keys():
        returns_dict = get_section_results(f, keys=['Eval_AverageReturn', 'Eval_StdReturn'])
        eval_returns, stds = returns_dict['Eval_AverageReturn'], returns_dict['Eval_StdReturn']
        plt.plot(range(len(eval_returns)), eval_returns, label=files_label_dict[f])
    
    plt.xlabel("Training Steps")
    plt.ylabel("Eval_AverageReturn")
    plt.title(title)
    plt.legend()
    
    plt.show()

# %%
plot_q5(q1_sb_files, title="Small Batch Evaluation Returns")
plot_q5(q1_lb_files, title="Large Batch Evaluation Returns")

# %% [markdown]
# ## Answer to 5:
# 1. The one with reward-to-go seem to converge faster, though in the end they converge to the same result
# 2. Advantage standardization doesn't seem to have a significant impact, standardization sometimes seem to hinder the convergence
# 3. Yes, batch size make the training converges faster

# %%
def get_comparison_b_lr(data_dir="5_2_data", batch_idx=1, lr_idx=2):
    import os
    all_logs = {}
    group_size = 5
    for root, dirs, files in os.walk(data_dir):
        if len(dirs) > 1:
            for d in sorted(dirs):
#                 print("*********** ", d)
                d_tokens = d.split("_")
                exp_name=d_tokens[batch_idx] + "_" + d_tokens[lr_idx]
                for r, dd, f in os.walk(os.path.join(data_dir, d)):
                    all_logs[os.path.join(r, f[0])] = exp_name
    return all_logs

def plot_comparison(all_logs, group_size):
    all_files = list(all_logs.keys()) 
    num_logs_graphed = 0
    group_idx = 0
    while num_logs_graphed < len(all_files):
        mini_logs = {}
        for f in all_files[num_logs_graphed: num_logs_graphed + group_size]:
            mini_logs[f] = all_logs[f]
        plot_q5(mini_logs, title="Group " + str(group_idx))
        group_idx += 1
        num_logs_graphed += group_size
    
plot_comparison(get_comparison_b_lr(), group_size=5)

# %%
lunar_logs={"LunarData/q3_b40000_r0.005_LunarLanderContinuous-v2_26-09-2020_23-04-39/events.out.tfevents.1601186679.heisenberg": "b40000_r0.005"}
plot_q5(lunar_logs, title="Lunar Lander Experiment")

# %%
plot_comparison(get_comparison_b_lr(data_dir="HalfCheetahData", batch_idx=4, lr_idx=5), group_size=3)

# %%
final_logs = {"FinalExperimentData/q4_b50000_r0.02_HalfCheetah-v2_27-09-2020_23-03-20/events.out.tfevents.1601273000.heisenberg": "Vanilla", 
              "FinalExperimentData/q4_b50000_r0.02_nnbaseline_HalfCheetah-v2_27-09-2020_23-03-14/events.out.tfevents.1601272994.heisenberg": "NN-Baseline", 
              "FinalExperimentData/q4_b50000_r0.02_rtg_HalfCheetah-v2_27-09-2020_23-03-16/events.out.tfevents.1601272996.heisenberg": "RTG", 
              "FinalExperimentData/q4_b50000_r0.02_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_23-03-07/events.out.tfevents.1601272987.heisenberg": "RTG and NN-Baseline"}

plot_q5(final_logs, title="Comparison of Various Optimizations")
